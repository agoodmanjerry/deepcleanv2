# %%
import os
import subprocess
import sys
from queue import Queue
from threading import Thread

from deepclean.couplings import subtraction_problems

# %% [markdown]
# ### Environment variables

# %%
HOME = "/home/chiajui.chou"
DEEPCLEAN_CONTAINER_ROOT = f"{HOME}/images/deepclean"
DEEPCLEAN_PROBLEM = "180Hz"
DATA_DIR = f"{HOME}/deepclean/data/CDC_test-{DEEPCLEAN_PROBLEM}"
RESULTS_DIR = f"{HOME}/deepclean/results"
DEEPCLEAN_IFO = "H1"
GPU_INDEX = 0
version = 1

# %% [markdown]
# ### Input to deepclean.tasks.Train

# %%
# luigi.cfg
cfg = dict.fromkeys(['deepclean', 'core'])
for key in cfg:
    cfg[key] = dict()

cfg['deepclean']['ifo'] = DEEPCLEAN_IFO
cfg['deepclean']['problem'] = DEEPCLEAN_PROBLEM
cfg['deepclean']['strain_channel'] = "GDS-CALIB_STRAIN"
cfg['core']['local_scheduler'] = True
cfg['core']['module'] = "deepclean"
# deepclean.config.deepclean
ifo = cfg['deepclean']['ifo']
problem = [cfg['deepclean']['problem']]
strain_channel = f"{ifo}:{cfg['deepclean']['strain_channel']}"
container_root = DEEPCLEAN_CONTAINER_ROOT
# subtraction problems
couplings = [subtraction_problems[i][ifo] for i in problem]
witnesses = [j for i in couplings for j in i.channels]
freq_low = [i.freq_low for i in couplings]
freq_high = [i.freq_high for i in couplings]
# train.sh and Train task
image = "train.sif"
gpus = GPU_INDEX
data_fname = f"{DATA_DIR}/deepclean-1378402219-3072.hdf5"
train_config = f"{HOME}/deepcleanv2/projects/train/config.yaml"
output_dir = f"{RESULTS_DIR}/O4-CDC_{DEEPCLEAN_PROBLEM}_dcprod"
config = train_config
channels = [strain_channel] + witnesses
freq_low = freq_low
freq_high = freq_high

# %% [markdown]
# ### stream_command

# %%
def read_stream(stream, process, q):
    stream = getattr(process, stream)
    try:
        it = iter(stream.readline, b"")
        while True:
            try:
                line = next(it)
            except StopIteration:
                break
            q.put(line.decode())
    finally:
        q.put(None)

def stream_process(process):
    q = Queue()
    args = (process, q)
    streams = ["stdout", "stderr"]
    threads = [Thread(target=read_stream, args=(i,) + args) for i in streams]
    for t in threads:
        t.start()

    for _ in range(2):
        for line in iter(q.get, None):
            sys.stdout.write(line)

def stream_command(command: list[str]):
    process = subprocess.Popen(
        command, stdout=subprocess.PIPE,
        stderr=subprocess.PIPE, env=os.environ
    )
    stream_process(process)

# %% [markdown]
# ### Run training

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpus)
command = [
    "python",
    "-m",
    "train",
    "--config",
    train_config,
    "--data.fname",
    data_fname,
    "--data.channels",
    "[" + ",".join(channels) + "]",
    "--data.freq_low",
    str(freq_low),
    "--data.freq_high",
    str(freq_high),
]
command.append(f"--trainer.logger.save_dir={output_dir}")
print(command)

if not os.path.exists(output_dir):
    os.mkdir(output_dir)

stream_command(command)
# Out:
# ['python', '-m', 'train', '--config', '/home/chiajui.chou/deepcleanv2/projects/train/config.yaml', '--data.fname', '/home/chiajui.chou/deepclean/data/CDC_test-180Hz/deepclean-1378402219-3072.hdf5', '--data.channels', '[H1:GDS-CALIB_STRAIN,H1:PEM-CS_MAG_LVEA_OUTPUTOPTICS_Z_DQ,H1:LSC-REFL_A_LF_OUT_DQ,H1:IMC-F_OUT_DQ,H1:IMC-WFS_B_Q_YAW_OUT_DQ,H1:IMC-WFS_A_Q_YAW_OUT_DQ,H1:PEM-EX_MAG_VEA_FLOOR_X_DQ,H1:PEM-CS_ACC_PSL_PERISCOPE_Y_DQ,H1:ISI-ITMY_ST2_BLND_RZ_GS13_CUR_IN1_DQ,H1:IMC-WFS_A_DC_YAW_OUT_DQ,H1:IMC-WFS_B_DC_YAW_OUT_DQ,H1:ISI-HAM6_BLND_GS13Z_IN1_DQ,H1:PEM-EY_VMON_ETMY_ESDPOWERMINUS18_DQ,H1:ISI-HAM2_BLND_GS13RZ_IN1_DQ,H1:IMC-L_OUT_DQ,H1:PEM-CS_ACC_PSL_PERISCOPE_X_DQ,H1:PEM-CS_MAG_EBAY_LSCRACK_Z_DQ,H1:IMC-DOF_4_Y_IN1_DQ,H1:IMC-WFS_B_I_YAW_OUT_DQ]', '--data.freq_low', '[176]', '--data.freq_high', '[184]', '--trainer.logger.save_dir=/home/chiajui.chou/deepclean/results/O4-CDC_180Hz_dcprod']
# Seed set to 101588
# You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: ModelCheckpoint
# You are using a CUDA device ('NVIDIA A30') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# /home/chiajui.chou/.cache/pypoetry/virtualenvs/clean-IeYuvgpU-py3.10/lib/python3.10/site-packages/lightning/fabric/loggers/csv_logs.py:268: Experiment logs directory /home/chiajui.chou/deepclean/results/O4-CDC_180Hz_dcprod/lightning_logs/version_1 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
# 2025-05-07 16:42:13,065 - DeepClean Dataset - INFO - Inferred data sample rate 4096.0Hz
# 2025-05-07 16:42:13,065 - DeepClean Dataset - INFO - Setting up data for fit stage
# 2025-05-07 16:42:13,065 - DeepClean Dataset - INFO - Loading train data
# 2025-05-07 16:42:16,951 - DeepClean Dataset - INFO - Training on first 687.0 seconds, validating on remaining 337.0 seconds
# 2025-05-07 16:42:16,951 - DeepClean Dataset - INFO - Preprocessing training data
# 2025-05-07 16:42:17,074 - DeepClean Dataset - INFO - Data loading complete
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name   | Type           | Params | Mode
# --------------------------------------------------
# 0 | model  | Autoencoder    | 41.6 K | train
# 1 | loss   | PsdRatio       | 0      | train
# 2 | metric | OnlinePsdRatio | 0      | train
# --------------------------------------------------
# 41.6 K    Trainable params
# 0         Non-trainable params
# 41.6 K    Total params
# 0.166     Total estimated model params size (MB)
# 36        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 508/508 [00:14<00:00, 35.91it/s, v_num=1, train_loss_step=0.790]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 515.21it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 137.86it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 112.14it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 109.13it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 107.11it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 64.93it/s]
# Epoch 1: 100%|██████████| 508/508 [00:13<00:00, 37.20it/s, v_num=1, train_loss_step=0.722, val_loss=0.775, train_loss_epoch=5.150]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 516.09it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 154.65it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 129.55it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 121.83it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 118.84it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 126.09it/s]
# Epoch 2: 100%|██████████| 508/508 [00:13<00:00, 37.26it/s, v_num=1, train_loss_step=0.713, val_loss=0.723, train_loss_epoch=0.738]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 523.70it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 149.05it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 126.20it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 119.64it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 116.81it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 126.49it/s]
# Epoch 3: 100%|██████████| 508/508 [00:13<00:00, 37.25it/s, v_num=1, train_loss_step=0.686, val_loss=0.711, train_loss_epoch=0.703]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 529.12it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 151.26it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 129.17it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 121.72it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 118.60it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 128.75it/s]
# Epoch 4: 100%|██████████| 508/508 [00:13<00:00, 37.28it/s, v_num=1, train_loss_step=0.676, val_loss=0.707, train_loss_epoch=0.692]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 544.22it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 151.09it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 127.28it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 120.57it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 117.51it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 127.78it/s]
# Epoch 5: 100%|██████████| 508/508 [00:13<00:00, 37.23it/s, v_num=1, train_loss_step=0.677, val_loss=0.711, train_loss_epoch=0.687]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 531.19it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 150.47it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 127.21it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 120.19it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 117.68it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00,

# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 561.64it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 145.88it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 122.28it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 116.35it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 113.30it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 122.94it/s]
# Epoch 21: 100%|██████████| 508/508 [00:13<00:00, 36.97it/s, v_num=1, train_loss_step=0.601, val_loss=0.740, train_loss_epoch=0.623]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 547.27it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 145.32it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 123.07it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 115.97it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 113.05it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 122.41it/s]
# Epoch 22: 100%|██████████| 508/508 [00:13<00:00, 36.93it/s, v_num=1, train_loss_step=0.605, val_loss=0.743, train_loss_epoch=0.617]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 556.20it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 146.23it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 120.78it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 114.66it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 111.64it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 120.84it/s]
# Epoch 23: 100%|██████████| 508/508 [00:13<00:00, 36.95it/s, v_num=1, train_loss_step=0.604, val_loss=0.729, train_loss_epoch=0.608]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 541.76it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 155.00it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 131.74it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 124.43it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 120.99it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 131.44it/s]
# Epoch 24: 100%|██████████| 508/508 [00:13<00:00, 36.97it/s, v_num=1, train_loss_step=0.571, val_loss=0.728, train_loss_epoch=0.602]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 557.16it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 153.98it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 130.10it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 122.90it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 119.75it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 129.99it/s]
# Epoch 25: 100%|██████████| 508/508 [00:13<00:00, 36.98it/s, v_num=1, train_loss_step=0.580, val_loss=0.734, train_loss_epoch=0.594]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 569.03it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 157.56it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 132.41it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 125.26it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 121.75it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 132.21it/s]
# Epoch 26: 100%|██████████| 508/508 [00:13<00:00, 36.96it/s, v_num=1, train_loss_step=0.566, val_loss=0.736, train_loss_epoch=0.581]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 541.06it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 152.23it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 128.58it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 121.13it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 117.48it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 127.06it/s]
# Epoch 27: 100%|██████████| 508/508 [00:13<00:00, 36.92it/s, v_num=1, train_loss_step=0.552, val_loss=0.737, train_loss_epoch=0.573]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 548.71it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 151.72it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 127.95it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 120.88it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 117.72it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 127.78it/s]
# Epoch 28: 100%|██████████| 508/508 [00:13<00:00, 36.92it/s, v_num=1, train_loss_step=0.570, val_loss=0.738, train_loss_epoch=0.563]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 532.75it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 150.70it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 127.33it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 120.04it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 116.66it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 126.44it/s]
# Epoch 29: 100%|██████████| 508/508 [00:13<00:00, 36.93it/s, v_num=1, train_loss_step=0.541, val_loss=0.738, train_loss_epoch=0.555]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 552.68it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 144.15it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 121.23it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 115.48it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 112.78it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 122.14it/s]
# Epoch 29: 100%|██████████| 508/508 [00:14<00:00, 36.05it/s, v_num=1, train_loss_step=0.541, val_loss=0.739, train_loss_epoch=0.544]
# The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: EarlyStopping, ModelCheckpoint, PsdPlotter
# 2025-05-07 16:49:20,019 - DeepClean Dataset - INFO - Inferred data sample rate 4096.0Hz
# 2025-05-07 16:49:20,019 - DeepClean Dataset - INFO - Setting up data for test stage
# 2025-05-07 16:49:20,019 - DeepClean Dataset - INFO - Loading test data
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 32/32 [00:02<00:00, 12.51it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss           0.7085517830635647
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### Clean

# %%
import yaml
sample_rate = 4096
version = version
train_dir = f"{HOME}/deepclean/results/O4-CDC_{DEEPCLEAN_PROBLEM}_dcprod/lightning_logs/version_{version}"
with open(f"{train_dir}/config.yaml", 'r') as file:
    train_config = yaml.safe_load(file)

data_dir = DATA_DIR
device = GPU_INDEX

# %%
# Load trained model and scalers
import torch
from ml4gw.transforms import ChannelWiseScaler
from utils.filt import BandpassFilter

model_path = f"{train_dir}/model.pt"
model = torch.jit.load(model_path).to(device)

strain_channel = train_config['data']['channels'][0]
witnesses = sorted(train_config['data']['channels'][1:])
num_witnesses = len(witnesses)
X_scaler = ChannelWiseScaler(num_channels=num_witnesses)
X_scaler_path = f"{train_dir}/X_scaler.pt"
X_scaler.load_state_dict(torch.load(X_scaler_path))

y_scaler = ChannelWiseScaler()
y_scaler_path = f"{train_dir}/y_scaler.pt"
y_scaler.load_state_dict(torch.load(y_scaler_path))

# bandpass filter
freq_low = train_config['data']['freq_low']
freq_high = train_config['data']['freq_high']
filt_order = int(train_config['data']['filt_order'])
bandpass = BandpassFilter(freq_low, freq_high, sample_rate, filt_order)

# %%
# Load data
import glob
from gwpy.timeseries import TimeSeriesDict

source = glob.glob(f"{data_dir}/*.hdf5")
data = TimeSeriesDict.read(source)
# Out:
# /home/chiajui.chou/.cache/pypoetry/virtualenvs/clean-IeYuvgpU-py3.10/lib/python3.10/site-packages/gwpy/time/__init__.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   from lal import LIGOTimeGPS

# %%
# Preprocess
from ml4gw.dataloading import InMemoryDataset

test_start = 1024
test_duration = 2048
infer_start = int(test_start * sample_rate)
infer_size = int(test_duration * sample_rate)
idx = slice(infer_start, infer_start + infer_size)

infer_y = torch.Tensor(data[strain_channel][idx])
infer_X = torch.zeros((num_witnesses, infer_size))
for i, channel in enumerate(witnesses):
    infer_X[i] = torch.Tensor(data[channel][idx])

infer_X = X_scaler(infer_X)

# Inference dataloader
clean_kernel_size = 8 * sample_rate
clean_stride = 4 * sample_rate
clean_batch_size = 128
X_inference = InMemoryDataset(
    infer_X,
    kernel_size=clean_kernel_size,
    stride=clean_stride,
    batch_size=clean_batch_size,
    coincident=True,
    shuffle=False,
    device=device,
)
y_inference = InMemoryDataset(
    infer_y,
    kernel_size=clean_kernel_size,
    stride=clean_stride,
    batch_size=clean_batch_size,
    coincident=True,
    shuffle=False,
    device=device,
)

# %%
# Inference
import numpy as np

prediction = []
for X, y in zip(iter(X_inference), iter(y_inference)):
    pred = model(X)
    prediction.append(pred.cpu().double().detach().numpy())

prediction = np.concatenate(prediction)

# %%
# Aggregating predictions (deepclean-prod)
N = prediction.shape[0]

# hanning window function
import scipy.signal as sig
window = "hann"
window_fn = sig.get_window(window, clean_kernel_size) * clean_stride / clean_kernel_size 

# Concatenate timeseries
nsamp = int((N - 1) * clean_stride + clean_kernel_size)
y_pred = np.zeros(nsamp)
for i in range(N):
    idx = slice(i*clean_stride, i*clean_stride + clean_kernel_size)
    y_pred[idx] += prediction[i]*window_fn

# Postprocess: reversed normalize, bandpass
noise = torch.Tensor(y_pred, device="cpu")
noise = y_scaler(noise.double(), reverse=True)
noise = bandpass(noise.detach().numpy())

# %%
# Clean
from gwpy.timeseries import TimeSeries
raw = infer_y.cpu().double().detach().numpy()
cleaned = raw - noise

# Save cleaned strain to gwf files
t0 = data[strain_channel].t0.value
duration = data[strain_channel].duration.value
channel = f"{strain_channel}_DC"

cleaned_ts = TimeSeries(
    cleaned,
    t0=t0,
    sample_rate=sample_rate,
    channel=channel,
)
raw = data[strain_channel].crop(t0, t0+duration)
raw_ts = TimeSeries(
    raw,
    t0=t0,
    sample_rate=sample_rate,
    channel=strain_channel,
)

output_file = f"/home/chiajui.chou/deepclean/dcprod-test/CDC_test-{DEEPCLEAN_PROBLEM}_dcprod-{int(t0)}-{int(duration)}_v{version}.hdf5"
format = "hdf5"
ts_dict = TimeSeriesDict()
ts_dict[channel] = cleaned_ts
ts_dict[strain_channel] = raw_ts
ts_dict.write(output_file, format=format)
