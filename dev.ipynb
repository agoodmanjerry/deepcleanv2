# %%
import os
import subprocess
import sys
from queue import Queue
from threading import Thread

from deepclean.couplings import subtraction_problems

# %% [markdown]
# ### Environment variables and config input

# %%
HOME = "/home/chiajui.chou"
DEEPCLEAN_IFO = "H1"
DEEPCLEAN_PROBLEM = "180Hz"
DATA_DIR = f"{HOME}/deepclean/data/CDC_test-{DEEPCLEAN_PROBLEM}"
RESULTS_DIR = f"{HOME}/deepclean/results"

# timeseries data
data_fname = f"{DATA_DIR}/deepclean-1378402219-3072.hdf5"

# subtraction problems
ifo = DEEPCLEAN_IFO
strain_channel = f"{ifo}:GDS-CALIB_STRAIN"
problem = [DEEPCLEAN_PROBLEM]
couplings = [subtraction_problems[i][ifo] for i in problem]
witnesses = [j for i in couplings for j in i.channels]
channels = [strain_channel] + witnesses
freq_low = [i.freq_low for i in couplings]
freq_high = [i.freq_high for i in couplings]

# Training
config = f"{HOME}/deepcleanv2/projects/train/config.yaml"
output_dir = f"{RESULTS_DIR}/O4-CDC_{DEEPCLEAN_PROBLEM}_test"
GPU_INDEX = 0
version = 0

# %% [markdown]
# ### stream_command

# %%
def read_stream(stream, process, q):
    stream = getattr(process, stream)
    try:
        it = iter(stream.readline, b"")
        while True:
            try:
                line = next(it)
            except StopIteration:
                break
            q.put(line.decode())
    finally:
        q.put(None)

def stream_process(process):
    q = Queue()
    args = (process, q)
    streams = ["stdout", "stderr"]
    threads = [Thread(target=read_stream, args=(i,) + args) for i in streams]
    for t in threads:
        t.start()

    for _ in range(2):
        for line in iter(q.get, None):
            sys.stdout.write(line)

def stream_command(command: list[str]):
    process = subprocess.Popen(
        command, stdout=subprocess.PIPE,
        stderr=subprocess.PIPE, env=os.environ
    )
    stream_process(process)

# %% [markdown]
# ### Run training

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = str(GPU_INDEX)
command = [
    "python",
    "-m",
    "train",
    "--config",
    config,
    "--data.fname",
    data_fname,
    "--data.channels",
    "[" + ",".join(channels) + "]",
    "--data.freq_low",
    str(freq_low),
    "--data.freq_high",
    str(freq_high),
]
command.append(f"--trainer.logger.save_dir={output_dir}")
print(command)

if not os.path.exists(output_dir):
    os.mkdir(output_dir)

stream_command(command)
# Out:
# ['python', '-m', 'train', '--config', '/home/chiajui.chou/deepcleanv2/projects/train/config.yaml', '--data.fname', '/home/chiajui.chou/deepclean/data/CDC_test-180Hz/deepclean-1378402219-3072.hdf5', '--data.channels', '[H1:GDS-CALIB_STRAIN,H1:PEM-CS_MAG_LVEA_OUTPUTOPTICS_Z_DQ,H1:LSC-REFL_A_LF_OUT_DQ,H1:IMC-F_OUT_DQ,H1:IMC-WFS_B_Q_YAW_OUT_DQ,H1:IMC-WFS_A_Q_YAW_OUT_DQ,H1:PEM-EX_MAG_VEA_FLOOR_X_DQ,H1:PEM-CS_ACC_PSL_PERISCOPE_Y_DQ,H1:ISI-ITMY_ST2_BLND_RZ_GS13_CUR_IN1_DQ,H1:IMC-WFS_A_DC_YAW_OUT_DQ,H1:IMC-WFS_B_DC_YAW_OUT_DQ,H1:ISI-HAM6_BLND_GS13Z_IN1_DQ,H1:PEM-EY_VMON_ETMY_ESDPOWERMINUS18_DQ,H1:ISI-HAM2_BLND_GS13RZ_IN1_DQ,H1:IMC-L_OUT_DQ,H1:PEM-CS_ACC_PSL_PERISCOPE_X_DQ,H1:PEM-CS_MAG_EBAY_LSCRACK_Z_DQ,H1:IMC-DOF_4_Y_IN1_DQ,H1:IMC-WFS_B_I_YAW_OUT_DQ]', '--data.freq_low', '[176]', '--data.freq_high', '[184]', '--trainer.logger.save_dir=/home/chiajui.chou/deepclean/results/O4-CDC_180Hz_test']
# Seed set to 101588
# You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: ModelCheckpoint
# You are using a CUDA device ('NVIDIA A30') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# /home/chiajui.chou/.cache/pypoetry/virtualenvs/clean-IeYuvgpU-py3.10/lib/python3.10/site-packages/lightning/fabric/loggers/csv_logs.py:268: Experiment logs directory /home/chiajui.chou/deepclean/results/O4-CDC_180Hz_test/lightning_logs/version_0 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
# 2025-05-08 01:44:58,977 - DeepClean Dataset - INFO - Inferred data sample rate 4096.0Hz
# 2025-05-08 01:44:58,977 - DeepClean Dataset - INFO - Setting up data for fit stage
# 2025-05-08 01:44:58,977 - DeepClean Dataset - INFO - Loading train data
# 2025-05-08 01:45:02,888 - DeepClean Dataset - INFO - Training on first 687.0 seconds, validating on remaining 337.0 seconds
# 2025-05-08 01:45:02,890 - DeepClean Dataset - INFO - Preprocessing training data
# 2025-05-08 01:45:03,110 - DeepClean Dataset - INFO - Data loading complete
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name   | Type           | Params | Mode
# --------------------------------------------------
# 0 | model  | Autoencoder    | 41.6 K | train
# 1 | loss   | PsdRatio       | 0      | train
# 2 | metric | OnlinePsdRatio | 0      | train
# --------------------------------------------------
# 41.6 K    Trainable params
# 0         Non-trainable params
# 41.6 K    Total params
# 0.166     Total estimated model params size (MB)
# 36        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 508/508 [00:14<00:00, 34.49it/s, v_num=0, train_loss_step=0.801]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 531.93it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 143.39it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 116.09it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 112.16it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 110.55it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 66.19it/s]
# Epoch 1: 100%|██████████| 508/508 [00:13<00:00, 37.18it/s, v_num=0, train_loss_step=0.717, val_loss=0.787, train_loss_epoch=5.140]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 533.76it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 151.26it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 126.84it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 120.19it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 116.82it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 126.76it/s]
# Epoch 2: 100%|██████████| 508/508 [00:13<00:00, 37.20it/s, v_num=0, train_loss_step=0.715, val_loss=0.721, train_loss_epoch=0.738]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 532.27it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 151.74it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 128.42it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 120.89it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 118.14it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 127.52it/s]
# Epoch 3: 100%|██████████| 508/508 [00:13<00:00, 37.19it/s, v_num=0, train_loss_step=0.684, val_loss=0.710, train_loss_epoch=0.701]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 549.06it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 151.78it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 127.97it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 120.97it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 117.29it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 127.06it/s]
# Epoch 4: 100%|██████████| 508/508 [00:13<00:00, 37.20it/s, v_num=0, train_loss_step=0.678, val_loss=0.709, train_loss_epoch=0.691]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 530.12it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 149.51it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 127.69it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 120.37it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 117.08it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 126.27it/s]
# Epoch 5: 100%|██████████| 508/508 [00:13<00:00, 37.16it/s, v_num=0, train_loss_step=0.676, val_loss=0.707, train_loss_epoch=0.687]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 546.06it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 148.23it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 124.54it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 117.75it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 114.93it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 124.91it/s]
# Epoch 6: 100%|██████████| 508/508 [00:13<00:00, 37.16it/s, v_num=0, train_loss_step=0.691, val_loss=0.705, train_loss_epoch=0.683]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 534.85it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 150.03it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 125.67it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 118.85it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 115.50it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 125.03it/s]
# Epoch 7: 100%|██████████| 508/508 [00:13<00:00, 37.23it/s, v_num=0, train_loss_step=0.673, val_loss=0.706, train_loss_epoch=0.682]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 526.39it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 141.90it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 120.44it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 113.61it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 110.60it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 119.20it/s]
# Epoch 8: 100%|██████████| 508/508 [00:13<00:00, 37.17it/s, v_num=0, train_loss_step=0.684, val_loss=0.706, train_loss_epoch=0.678]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 554.51it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 148.67it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 125.04it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 118

# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 546.85it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 149.43it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 126.70it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 119.35it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 115.78it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 125.31it/s]
# Epoch 24: 100%|██████████| 508/508 [00:13<00:00, 36.91it/s, v_num=0, train_loss_step=0.570, val_loss=0.723, train_loss_epoch=0.610]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 527.06it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 149.46it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 126.25it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 119.54it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 116.57it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 125.69it/s]
# Epoch 25: 100%|██████████| 508/508 [00:13<00:00, 36.92it/s, v_num=0, train_loss_step=0.587, val_loss=0.725, train_loss_epoch=0.597]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 555.54it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 152.70it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 127.57it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 119.98it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 116.61it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 125.98it/s]
# Epoch 26: 100%|██████████| 508/508 [00:13<00:00, 36.93it/s, v_num=0, train_loss_step=0.580, val_loss=0.723, train_loss_epoch=0.588]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 554.07it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 149.84it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 126.02it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 119.51it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 116.91it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 126.55it/s]
# Epoch 27: 100%|██████████| 508/508 [00:13<00:00, 36.92it/s, v_num=0, train_loss_step=0.544, val_loss=0.724, train_loss_epoch=0.577]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 556.72it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 152.08it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 128.24it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 120.33it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 116.95it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 126.53it/s]
# Epoch 28: 100%|██████████| 508/508 [00:13<00:00, 36.91it/s, v_num=0, train_loss_step=0.551, val_loss=0.723, train_loss_epoch=0.567]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 528.05it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 149.87it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 126.59it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 119.69it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 116.37it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 125.17it/s]
# Epoch 29: 100%|██████████| 508/508 [00:13<00:00, 36.91it/s, v_num=0, train_loss_step=0.531, val_loss=0.786, train_loss_epoch=0.564]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Validation DataLoader 0:  17%|█▋        | 1/6 [00:00<00:00, 555.83it/s]
# Validation DataLoader 0:  33%|███▎      | 2/6 [00:00<00:00, 150.12it/s]
# Validation DataLoader 0:  50%|█████     | 3/6 [00:00<00:00, 126.94it/s]
# Validation DataLoader 0:  67%|██████▋   | 4/6 [00:00<00:00, 119.81it/s]
# Validation DataLoader 0:  83%|████████▎ | 5/6 [00:00<00:00, 116.76it/s]
# Validation DataLoader 0: 100%|██████████| 6/6 [00:00<00:00, 126.09it/s]
# Epoch 29: 100%|██████████| 508/508 [00:14<00:00, 36.07it/s, v_num=0, train_loss_step=0.531, val_loss=0.778, train_loss_epoch=0.547]
# The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: EarlyStopping, ModelCheckpoint, PsdPlotter
# 2025-05-08 01:52:10,309 - DeepClean Dataset - INFO - Inferred data sample rate 4096.0Hz
# 2025-05-08 01:52:10,309 - DeepClean Dataset - INFO - Setting up data for test stage
# 2025-05-08 01:52:10,309 - DeepClean Dataset - INFO - Loading test data
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 32/32 [00:02<00:00, 12.74it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss           0.7022648340167646
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### Clean

# %%
import glob
import yaml
import numpy as np
import scipy.signal as sig
from gwpy.timeseries import TimeSeriesDict

import torch
from ml4gw.transforms import ChannelWiseScaler
from ml4gw.dataloading import InMemoryDataset
from utils.filt import BandpassFilter

# %% [markdown]
# ### Config input

# %%
# Model loading
sample_rate = 4096
version = version
train_dir = f"{output_dir}/lightning_logs/version_{version}"
with open(f"{train_dir}/config.yaml", 'r') as file:
    train_config = yaml.safe_load(file)

data_dir = DATA_DIR
data_source = glob.glob(f"{data_dir}/*.hdf5")
device = GPU_INDEX

# Data loading and preprocessing
test_start = 1024
test_duration = 2048
clean_kernel_size = 8 * sample_rate
clean_stride = 4 * sample_rate
clean_batch_size = 128

# Inference
window = "hann"

# Clean and write
channel = f"{strain_channel}_DC"
format = "hdf5"
out_dir = f"/home/chiajui.chou/deepclean/dcprod-test"
out_label = f"CDC_test-{DEEPCLEAN_PROBLEM}_dcprod_v{version}"

# %% [markdown]
# ### Load model

# %%
# Load trained model and scalers
model_path = f"{train_dir}/model.pt"
model = torch.jit.load(model_path).to(device)

strain_channel = train_config['data']['channels'][0]
witnesses = sorted(train_config['data']['channels'][1:])
num_witnesses = len(witnesses)
X_scaler = ChannelWiseScaler(num_channels=num_witnesses)
X_scaler_path = f"{train_dir}/X_scaler.pt"
X_scaler.load_state_dict(torch.load(X_scaler_path))

y_scaler = ChannelWiseScaler()
y_scaler_path = f"{train_dir}/y_scaler.pt"
y_scaler.load_state_dict(torch.load(y_scaler_path))

# bandpass filter
freq_low = train_config['data']['freq_low']
freq_high = train_config['data']['freq_high']
filt_order = int(train_config['data']['filt_order'])
bandpass = BandpassFilter(freq_low, freq_high, sample_rate, filt_order)

# %% [markdown]
# ### Load data

# %%
# Load data
source = data_source
data = TimeSeriesDict.read(source)

# Preprocess
infer_start = int(test_start * sample_rate)
infer_size = int(test_duration * sample_rate)
idx = slice(infer_start, infer_start + infer_size)

infer_y = torch.Tensor(data[strain_channel][idx])
infer_X = torch.zeros((num_witnesses, infer_size))
for i, channel in enumerate(witnesses):
    infer_X[i] = torch.Tensor(data[channel][idx])

infer_X = X_scaler(infer_X)

# Inference dataloader
X_inference = InMemoryDataset(
    infer_X,
    kernel_size=clean_kernel_size,
    stride=clean_stride,
    batch_size=clean_batch_size,
    coincident=True,
    shuffle=False,
    device=device,
)
y_inference = InMemoryDataset(
    infer_y,
    kernel_size=clean_kernel_size,
    stride=clean_stride,
    batch_size=clean_batch_size,
    coincident=True,
    shuffle=False,
    device=device,
)

# %% [markdown]
# ### Inference

# %%
# Inference
prediction = []
for X, y in zip(iter(X_inference), iter(y_inference)):
    pred = model(X)
    prediction.append(pred.cpu().double().detach().numpy())

prediction = np.concatenate(prediction)

# Aggregating predictions (deepclean-prod)
N = prediction.shape[0]

# hanning window function
window_fn = sig.get_window(window, clean_kernel_size) * clean_stride / clean_kernel_size 

# Concatenate timeseries
nsamp = int((N - 1) * clean_stride + clean_kernel_size)
y_pred = np.zeros(nsamp)
for i in range(N):
    idx = slice(i*clean_stride, i*clean_stride + clean_kernel_size)
    y_pred[idx] += prediction[i]*window_fn

# Postprocess: reversed normalize, bandpass
noise = torch.Tensor(y_pred, device="cpu")
noise = y_scaler(noise.double(), reverse=True)
noise = bandpass(noise.detach().numpy())

# %%
# Aggregating predictions (deepclean-prod)
N = prediction.shape[0]

# hanning window function
window_fn = sig.get_window(window, clean_kernel_size) * clean_stride / clean_kernel_size 

# Concatenate timeseries
nsamp = int((N - 1) * clean_stride + clean_kernel_size)
y_pred = np.zeros(nsamp)
for i in range(N):
    idx = slice(i*clean_stride, i*clean_stride + clean_kernel_size)
    y_pred[idx] += prediction[i]*window_fn

# Postprocess: reversed normalize, bandpass
noise = torch.Tensor(y_pred, device="cpu")
noise = y_scaler(noise.double(), reverse=True)
noise = bandpass(noise.detach().numpy())

# %% [markdown]
# ### Clean and write cleaned data

# %%
# Clean
from gwpy.timeseries import TimeSeries
raw = infer_y.cpu().double().detach().numpy()
cleaned = raw - noise

# Save cleaned strain to gwf files
t0 = data[strain_channel].t0.value
duration = data[strain_channel].duration.value

cleaned_ts = TimeSeries(
    cleaned,
    t0=t0,
    sample_rate=sample_rate,
    channel=channel,
)
raw = data[strain_channel].crop(t0, t0+duration)
raw_ts = TimeSeries(
    raw,
    t0=t0,
    sample_rate=sample_rate,
    channel=strain_channel,
)

output_file = f"{out_dir}/{out_label}-{int(t0)}-{int(duration)}.{format}"
ts_dict = TimeSeriesDict()
ts_dict[channel] = cleaned_ts
ts_dict[strain_channel] = raw_ts
ts_dict.write(output_file, format=format)
